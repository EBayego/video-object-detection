# %% [markdown]
# # Method that allows you to draw bounding boxes on the objects in all the images within a directory

# %%
import os
import cv2
import json

# %%
class ImageAreaSelector:
    def __init__(self):
        self.refPt = []
        self.areas = []
        self.cropping = False

    def click_and_crop(self, event, x, y, flags, param):
        if event == cv2.EVENT_LBUTTONDOWN:
            self.refPt = [(x, y)]
            self.cropping = True
            self.image_with_rect = self.image.copy()

        elif event == cv2.EVENT_MOUSEMOVE:
            if self.cropping:
                temp_image = self.image_with_rect.copy()
                cv2.rectangle(temp_image, self.refPt[0], (x, y), (0, 255, 0), 2)
                cv2.imshow("image", temp_image)

        elif event == cv2.EVENT_LBUTTONUP:
            self.refPt.append((x, y))
            self.cropping = False
            cv2.rectangle(self.image_with_rect, self.refPt[0], (x, y), (0, 255, 0), 2)
            cv2.imshow("image", self.image_with_rect)
            self.areas.append(self.refPt)

    def select_areas(self, image):
        self.image = image.copy()
        self.image_with_rect = image.copy()
        cv2.namedWindow("image")
        cv2.imshow("image", self.image) 
        cv2.setMouseCallback("image", self.click_and_crop)

    def remove_last_area(self):
        if self.areas:
            self.areas.pop()
            self.image_with_rect = self.image.copy()
            for area in self.areas:
                cv2.rectangle(self.image_with_rect, area[0], area[1], (0, 255, 0), 2)
            cv2.imshow("image", self.image_with_rect)

# %% [markdown]
# ## Press space to move to the next image and "d" to delete last bounding box

# %% [markdown]
# After passing through all the images, save the data in the desired format for Faster RCNN in a .json file.

# %%
image_folder = "./images/keys"
image_files = [f for f in os.listdir(image_folder) if f.endswith('.jpg')]
image_files = sorted(image_files, key=lambda x: int(x.split("_")[-1].split(".")[0]))
areas_dict = {}

annotations = []
categories = [
    {"id": 91, "name": "keys"},
    {"id": 92, "name": "pencil"},
    {"id": 93, "name": "sneakers"}
]

selector = ImageAreaSelector()

for idx, image_file in enumerate(image_files):
    image_path = os.path.join(image_folder, image_file)
    image = cv2.imread(image_path)
    if image is None:
        print(f"No se pudo cargar la imagen {image_file}")
        continue

    selector.select_areas(image)
    while True:
        key = cv2.waitKey(1) & 0xFF
        if key == ord(" "):  # If the space key is pressed, move to the next one
            break
        elif key == ord("d"):  # If "d" is pressed, delete last bounding box
            selector.remove_last_area()

    areas_dict[image_file] = selector.areas
    
    for area in areas_dict[image_file]:
        xmin, ymin = area[0]
        xmax, ymax = area[1]
        print ("xmin, ymin, xmax, ymax :", xmin, ymin, xmax, ymax)
        if "llaves" in image_file:
            category_id = 91
        elif "pencil" in image_file:
            category_id = 92
        elif "zapatilas" in image_file:
            category_id = 93
        else:
            category_id = 0  # Otra categoría por defecto
        annotations.append({"image_id": idx, "category_id": category_id, "bbox": [xmin, xmax, ymin, ymax]})
        print("annotations: ", annotations[-1])
        
    selector.areas = []

    cv2.destroyAllWindows()

json_data = {"annotations": annotations, "categories": categories, "images": [{"id": i, "file_name": image_files[i]} for i in range(len(image_files))]}

with open("annotations_perso.json", "w") as json_file:
    json.dump(json_data, json_file, indent=4)

print("Annotations saved to annotations_perso.json")
# Out:
# xmin, ymin, xmax, ymax : 21 12 150 93
# annotations:  {'image_id': 0, 'category_id': 91, 'bbox': [21, 150, 12, 93]}
# xmin, ymin, xmax, ymax : 4 67 156 4
# annotations:  {'image_id': 1, 'category_id': 91, 'bbox': [4, 156, 67, 4]}
# xmin, ymin, xmax, ymax : 1 2 137 139
# annotations:  {'image_id': 2, 'category_id': 91, 'bbox': [1, 137, 2, 139]}
# xmin, ymin, xmax, ymax : 4 6 155 95
# annotations:  {'image_id': 3, 'category_id': 91, 'bbox': [4, 155, 6, 95]}
# xmin, ymin, xmax, ymax : 8 98 152 14
# annotations:  {'image_id': 4, 'category_id': 91, 'bbox': [8, 152, 98, 14]}
# xmin, ymin, xmax, ymax : 5 112 159 22
# annotations:  {'image_id': 5, 'category_id': 91, 'bbox': [5, 159, 112, 22]}
# xmin, ymin, xmax, ymax : 8 139 134 -1
# annotations:  {'image_id': 6, 'category_id': 91, 'bbox': [8, 134, 139, -1]}
# xmin, ymin, xmax, ymax : 79 27 128 141
# annotations:  {'image_id': 6, 'category_id': 91, 'bbox': [79, 128, 27, 141]}
# xmin, ymin, xmax, ymax : 2 80 160 -1
# annotations:  {'image_id': 7, 'category_id': 91, 'bbox': [2, 160, 80, -1]}
# xmin, ymin, xmax, ymax : 3 52 72 -1
# annotations:  {'image_id': 7, 'category_id': 91, 'bbox': [3, 72, 52, -1]}
# xmin, ymin, xmax, ymax : 75 15 103 79
# annotations:  {'image_id': 7, 'category_id': 91, 'bbox': [75, 103, 15, 79]}
# xmin, ymin, xmax, ymax : 39 101 129 11
# annotations:  {'image_id': 8, 'category_id': 91, 'bbox': [39, 129, 101, 11]}
# xmin, ymin, xmax, ymax : 28 89 128 0
# annotations:  {'image_id': 9, 'category_id': 91, 'bbox': [28, 128, 89, 0]}
# xmin, ymin, xmax, ymax : 60 91 109 46
# annotations:  {'image_id': 10, 'category_id': 91, 'bbox': [60, 109, 91, 46]}
# xmin, ymin, xmax, ymax : 56 14 106 43
# annotations:  {'image_id': 11, 'category_id': 91, 'bbox': [56, 106, 14, 43]}
# xmin, ymin, xmax, ymax : 22 112 132 8
# annotations:  {'image_id': 12, 'category_id': 91, 'bbox': [22, 132, 112, 8]}
# xmin, ymin, xmax, ymax : 6 117 147 17
# annotations:  {'image_id': 13, 'category_id': 91, 'bbox': [6, 147, 117, 17]}
# xmin, ymin, xmax, ymax : 141 114 45 57
# annotations:  {'image_id': 13, 'category_id': 91, 'bbox': [141, 45, 114, 57]}
# xmin, ymin, xmax, ymax : 45 81 80 20
# annotations:  {'image_id': 14, 'category_id': 91, 'bbox': [45, 80, 81, 20]}
# xmin, ymin, xmax, ymax : 8 126 84 4
# annotations:  {'image_id': 15, 'category_id': 91, 'bbox': [8, 84, 126, 4]}
# xmin, ymin, xmax, ymax : 11 113 49 38
# annotations:  {'image_id': 15, 'category_id': 91, 'bbox': [11, 49, 113, 38]}
# xmin, ymin, xmax, ymax : 2 139 125 1
# annotations:  {'image_id': 16, 'category_id': 91, 'bbox': [2, 125, 139, 1]}
# xmin, ymin, xmax, ymax : 3 137 57 22
# annotations:  {'image_id': 16, 'category_id': 91, 'bbox': [3, 57, 137, 22]}
# xmin, ymin, xmax, ymax : 14 134 123 5
# annotations:  {'image_id': 17, 'category_id': 91, 'bbox': [14, 123, 134, 5]}
# xmin, ymin, xmax, ymax : 35 43 77 112
# annotations:  {'image_id': 18, 'category_id': 91, 'bbox': [35, 77, 43, 112]}
# xmin, ymin, xmax, ymax : 92 21 167 72
# annotations:  {'image_id': 18, 'category_id': 91, 'bbox': [92, 167, 21, 72]}
# xmin, ymin, xmax, ymax : 6 10 27 68
# annotations:  {'image_id': 19, 'category_id': 91, 'bbox': [6, 27, 10, 68]}
# xmin, ymin, xmax, ymax : 30 8 53 69
# annotations:  {'image_id': 19, 'category_id': 91, 'bbox': [30, 53, 8, 69]}
# xmin, ymin, xmax, ymax : 55 7 77 69
# annotations:  {'image_id': 19, 'category_id': 91, 'bbox': [55, 77, 7, 69]}
# xmin, ymin, xmax, ymax : 78 8 101 66
# annotations:  {'image_id': 19, 'category_id': 91, 'bbox': [78, 101, 8, 66]}
# xmin, ymin, xmax, ymax : 104 9 128 70
# annotations:  {'image_id': 19, 'category_id': 91, 'bbox': [104, 128, 9, 70]}
# xmin, ymin, xmax, ymax : 130 8 154 71
# annotations:  {'image_id': 19, 'category_id': 91, 'bbox': [130, 154, 8, 71]}
# xmin, ymin, xmax, ymax : 15 2 156 105
# annotations:  {'image_id': 20, 'category_id': 91, 'bbox': [15, 156, 2, 105]}
# xmin, ymin, xmax, ymax : 39 137 102 5
# annotations:  {'image_id': 21, 'category_id': 91, 'bbox': [39, 102, 137, 5]}
# xmin, ymin, xmax, ymax : 3 119 153 4
# annotations:  {'image_id': 22, 'category_id': 91, 'bbox': [3, 153, 119, 4]}
# xmin, ymin, xmax, ymax : 45 2 78 21
# annotations:  {'image_id': 23, 'category_id': 91, 'bbox': [45, 78, 2, 21]}
# xmin, ymin, xmax, ymax : 78 29 91 2
# annotations:  {'image_id': 23, 'category_id': 91, 'bbox': [78, 91, 29, 2]}
# xmin, ymin, xmax, ymax : 94 19 128 38
# annotations:  {'image_id': 23, 'category_id': 91, 'bbox': [94, 128, 19, 38]}
# xmin, ymin, xmax, ymax : 131 2 147 39
# annotations:  {'image_id': 23, 'category_id': 91, 'bbox': [131, 147, 2, 39]}
# xmin, ymin, xmax, ymax : 147 2 166 40
# annotations:  {'image_id': 23, 'category_id': 91, 'bbox': [147, 166, 2, 40]}
# xmin, ymin, xmax, ymax : 99 62 136 83
# annotations:  {'image_id': 23, 'category_id': 91, 'bbox': [99, 136, 62, 83]}
# xmin, ymin, xmax, ymax : 133 103 151 65
# annotations:  {'image_id': 23, 'category_id': 91, 'bbox': [133, 151, 103, 65]}
# xmin, ymin, xmax, ymax : 78 100 116 116
# annotations:  {'image_id': 23, 'category_id': 91, 'bbox': [78, 116, 100, 116]}
# xmin, ymin, xmax, ymax : 28 97 64 116
# annotations:  {'image_id': 23, 'category_id': 91, 'bbox': [28, 64, 97, 116]}
# xmin, ymin, xmax, ymax : 46 69 64 104
# annotations:  {'image_id': 23, 'category_id': 91, 'bbox': [46, 64, 69, 104]}
# xmin, ymin, xmax, ymax : 13 49 -3 81
# annotations:  {'image_id': 23, 'category_id': 91, 'bbox': [13, -3, 49, 81]}
# xmin, ymin, xmax, ymax : 30 35 -8 20
# annotations:  {'image_id': 23, 'category_id': 91, 'bbox': [30, -8, 35, 20]}
# xmin, ymin, xmax, ymax : 15 48 32 82
# annotations:  {'image_id': 23, 'category_id': 91, 'bbox': [15, 32, 48, 82]}
# xmin, ymin, xmax, ymax : 29 117 -4 96
# annotations:  {'image_id': 23, 'category_id': 91, 'bbox': [29, -4, 117, 96]}
# xmin, ymin, xmax, ymax : 10 35 98 117
# annotations:  {'image_id': 24, 'category_id': 91, 'bbox': [10, 98, 35, 117]}
# xmin, ymin, xmax, ymax : 38 13 101 121
# annotations:  {'image_id': 25, 'category_id': 91, 'bbox': [38, 101, 13, 121]}
# xmin, ymin, xmax, ymax : 34 9 136 102
# annotations:  {'image_id': 26, 'category_id': 91, 'bbox': [34, 136, 9, 102]}
# xmin, ymin, xmax, ymax : 18 75 137 13
# annotations:  {'image_id': 27, 'category_id': 91, 'bbox': [18, 137, 75, 13]}
# xmin, ymin, xmax, ymax : 23 116 155 3
# annotations:  {'image_id': 28, 'category_id': 91, 'bbox': [23, 155, 116, 3]}
# xmin, ymin, xmax, ymax : 1 136 111 7
# annotations:  {'image_id': 29, 'category_id': 91, 'bbox': [1, 111, 136, 7]}
# xmin, ymin, xmax, ymax : 63 12 158 109
# annotations:  {'image_id': 30, 'category_id': 91, 'bbox': [63, 158, 12, 109]}
# xmin, ymin, xmax, ymax : 60 85 79 122
# annotations:  {'image_id': 31, 'category_id': 91, 'bbox': [60, 79, 85, 122]}
# xmin, ymin, xmax, ymax : 5 4 130 134
# annotations:  {'image_id': 32, 'category_id': 91, 'bbox': [5, 130, 4, 134]}
# xmin, ymin, xmax, ymax : 1 139 135 -1
# annotations:  {'image_id': 33, 'category_id': 91, 'bbox': [1, 135, 139, -1]}
# xmin, ymin, xmax, ymax : 11 33 156 84
# annotations:  {'image_id': 34, 'category_id': 91, 'bbox': [11, 156, 33, 84]}
# xmin, ymin, xmax, ymax : 12 119 122 28
# annotations:  {'image_id': 35, 'category_id': 91, 'bbox': [12, 122, 119, 28]}
# xmin, ymin, xmax, ymax : 3 0 159 103
# annotations:  {'image_id': 36, 'category_id': 91, 'bbox': [3, 159, 0, 103]}
# xmin, ymin, xmax, ymax : 4 22 161 84
# annotations:  {'image_id': 37, 'category_id': 91, 'bbox': [4, 161, 22, 84]}
# xmin, ymin, xmax, ymax : 13 6 146 66
# annotations:  {'image_id': 38, 'category_id': 91, 'bbox': [13, 146, 6, 66]}
# xmin, ymin, xmax, ymax : 10 2 122 131
# annotations:  {'image_id': 39, 'category_id': 91, 'bbox': [10, 122, 2, 131]}
# xmin, ymin, xmax, ymax : 10 128 138 15
# annotations:  {'image_id': 40, 'category_id': 91, 'bbox': [10, 138, 128, 15]}
# xmin, ymin, xmax, ymax : 3 138 47 45
# annotations:  {'image_id': 41, 'category_id': 91, 'bbox': [3, 47, 138, 45]}
# xmin, ymin, xmax, ymax : 6 1 74 136
# annotations:  {'image_id': 42, 'category_id': 91, 'bbox': [6, 74, 1, 136]}
# xmin, ymin, xmax, ymax : 1 78 158 -1
# annotations:  {'image_id': 43, 'category_id': 91, 'bbox': [1, 158, 78, -1]}
# xmin, ymin, xmax, ymax : 38 37 160 80
# annotations:  {'image_id': 43, 'category_id': 91, 'bbox': [38, 160, 37, 80]}
# xmin, ymin, xmax, ymax : 47 26 154 72
# annotations:  {'image_id': 44, 'category_id': 91, 'bbox': [47, 154, 26, 72]}
# xmin, ymin, xmax, ymax : 30 130 142 12
# annotations:  {'image_id': 45, 'category_id': 91, 'bbox': [30, 142, 130, 12]}
# xmin, ymin, xmax, ymax : 2 116 129 14
# annotations:  {'image_id': 46, 'category_id': 91, 'bbox': [2, 129, 116, 14]}
# xmin, ymin, xmax, ymax : 45 55 157 106
# annotations:  {'image_id': 47, 'category_id': 91, 'bbox': [45, 157, 55, 106]}
# xmin, ymin, xmax, ymax : 35 53 140 7
# annotations:  {'image_id': 47, 'category_id': 91, 'bbox': [35, 140, 53, 7]}
# xmin, ymin, xmax, ymax : 28 96 130 27
# annotations:  {'image_id': 48, 'category_id': 91, 'bbox': [28, 130, 96, 27]}
# xmin, ymin, xmax, ymax : 1 1 161 100
# annotations:  {'image_id': 49, 'category_id': 91, 'bbox': [1, 161, 1, 100]}
# xmin, ymin, xmax, ymax : 38 88 8 22
# annotations:  {'image_id': 50, 'category_id': 91, 'bbox': [38, 8, 88, 22]}
# xmin, ymin, xmax, ymax : 77 84 43 18
# annotations:  {'image_id': 50, 'category_id': 91, 'bbox': [77, 43, 84, 18]}
# xmin, ymin, xmax, ymax : 4 75 157 5
# annotations:  {'image_id': 51, 'category_id': 91, 'bbox': [4, 157, 75, 5]}
# xmin, ymin, xmax, ymax : 10 95 158 20
# annotations:  {'image_id': 52, 'category_id': 91, 'bbox': [10, 158, 95, 20]}
# xmin, ymin, xmax, ymax : 2 112 158 17
# annotations:  {'image_id': 53, 'category_id': 91, 'bbox': [2, 158, 112, 17]}
# xmin, ymin, xmax, ymax : 1 92 80 18
# annotations:  {'image_id': 53, 'category_id': 91, 'bbox': [1, 80, 92, 18]}
# xmin, ymin, xmax, ymax : 3 126 154 2
# annotations:  {'image_id': 54, 'category_id': 91, 'bbox': [3, 154, 126, 2]}
# xmin, ymin, xmax, ymax : 12 105 92 9
# annotations:  {'image_id': 54, 'category_id': 91, 'bbox': [12, 92, 105, 9]}
# xmin, ymin, xmax, ymax : 3 139 135 12
# annotations:  {'image_id': 55, 'category_id': 91, 'bbox': [3, 135, 139, 12]}
# xmin, ymin, xmax, ymax : 14 135 139 11
# annotations:  {'image_id': 56, 'category_id': 91, 'bbox': [14, 139, 135, 11]}
# xmin, ymin, xmax, ymax : 19 133 101 34
# annotations:  {'image_id': 56, 'category_id': 91, 'bbox': [19, 101, 133, 34]}
# xmin, ymin, xmax, ymax : 4 85 154 9
# annotations:  {'image_id': 57, 'category_id': 91, 'bbox': [4, 154, 85, 9]}
# xmin, ymin, xmax, ymax : 5 48 153 3
# annotations:  {'image_id': 58, 'category_id': 91, 'bbox': [5, 153, 48, 3]}
# xmin, ymin, xmax, ymax : 121 39 145 8
# annotations:  {'image_id': 58, 'category_id': 91, 'bbox': [121, 145, 39, 8]}
# xmin, ymin, xmax, ymax : 16 8 58 30
# annotations:  {'image_id': 58, 'category_id': 91, 'bbox': [16, 58, 8, 30]}
# xmin, ymin, xmax, ymax : 47 12 79 68
# annotations:  {'image_id': 59, 'category_id': 91, 'bbox': [47, 79, 12, 68]}
# xmin, ymin, xmax, ymax : 6 119 47 62
# annotations:  {'image_id': 59, 'category_id': 91, 'bbox': [6, 47, 119, 62]}
# xmin, ymin, xmax, ymax : 37 8 55 48
# annotations:  {'image_id': 60, 'category_id': 91, 'bbox': [37, 55, 8, 48]}
# xmin, ymin, xmax, ymax : 96 82 106 107
# annotations:  {'image_id': 60, 'category_id': 91, 'bbox': [96, 106, 82, 107]}
# xmin, ymin, xmax, ymax : 96 61 106 35
# annotations:  {'image_id': 60, 'category_id': 91, 'bbox': [96, 106, 61, 35]}
# xmin, ymin, xmax, ymax : 54 21 67 41
# annotations:  {'image_id': 61, 'category_id': 91, 'bbox': [54, 67, 21, 41]}
# xmin, ymin, xmax, ymax : 23 35 34 54
# annotations:  {'image_id': 61, 'category_id': 91, 'bbox': [23, 34, 35, 54]}
# xmin, ymin, xmax, ymax : 17 4 33 39
# annotations:  {'image_id': 62, 'category_id': 91, 'bbox': [17, 33, 4, 39]}
# xmin, ymin, xmax, ymax : 36 5 49 36
# annotations:  {'image_id': 62, 'category_id': 91, 'bbox': [36, 49, 5, 36]}
# xmin, ymin, xmax, ymax : 51 3 64 36
# annotations:  {'image_id': 62, 'category_id': 91, 'bbox': [51, 64, 3, 36]}
# xmin, ymin, xmax, ymax : 77 8 90 34
# annotations:  {'image_id': 62, 'category_id': 91, 'bbox': [77, 90, 8, 34]}
# xmin, ymin, xmax, ymax : 62 5 78 34
# annotations:  {'image_id': 62, 'category_id': 91, 'bbox': [62, 78, 5, 34]}
# xmin, ymin, xmax, ymax : 17 36 32 64
# annotations:  {'image_id': 62, 'category_id': 91, 'bbox': [17, 32, 36, 64]}
# xmin, ymin, xmax, ymax : 13 64 33 99
# annotations:  {'image_id': 62, 'category_id': 91, 'bbox': [13, 33, 64, 99]}
# xmin, ymin, xmax, ymax : 63 35 76 66
# annotations:  {'image_id': 62, 'category_id': 91, 'bbox': [63, 76, 35, 66]}
# xmin, ymin, xmax, ymax : 75 70 90 104
# annotations:  {'image_id': 62, 'category_id': 91, 'bbox': [75, 90, 70, 104]}
# xmin, ymin, xmax, ymax : 24 92 153 17
# annotations:  {'image_id': 63, 'category_id': 91, 'bbox': [24, 153, 92, 17]}
# xmin, ymin, xmax, ymax : 36 15 105 124
# annotations:  {'image_id': 64, 'category_id': 91, 'bbox': [36, 105, 15, 124]}
# xmin, ymin, xmax, ymax : 153 78 13 12
# annotations:  {'image_id': 65, 'category_id': 91, 'bbox': [153, 13, 78, 12]}
# xmin, ymin, xmax, ymax : 81 26 125 79
# annotations:  {'image_id': 65, 'category_id': 91, 'bbox': [81, 125, 26, 79]}
# xmin, ymin, xmax, ymax : 20 100 140 6
# annotations:  {'image_id': 66, 'category_id': 91, 'bbox': [20, 140, 100, 6]}
# xmin, ymin, xmax, ymax : 34 111 101 31
# annotations:  {'image_id': 68, 'category_id': 91, 'bbox': [34, 101, 111, 31]}
# xmin, ymin, xmax, ymax : 18 98 129 11
# annotations:  {'image_id': 69, 'category_id': 91, 'bbox': [18, 129, 98, 11]}
# xmin, ymin, xmax, ymax : 0 127 139 17
# annotations:  {'image_id': 70, 'category_id': 91, 'bbox': [0, 139, 127, 17]}
# xmin, ymin, xmax, ymax : 16 45 57 115
# annotations:  {'image_id': 70, 'category_id': 91, 'bbox': [16, 57, 45, 115]}
# xmin, ymin, xmax, ymax : 88 23 9 102
# annotations:  {'image_id': 71, 'category_id': 91, 'bbox': [88, 9, 23, 102]}
# xmin, ymin, xmax, ymax : 35 87 118 20
# annotations:  {'image_id': 72, 'category_id': 91, 'bbox': [35, 118, 87, 20]}
# xmin, ymin, xmax, ymax : 2 98 154 2
# annotations:  {'image_id': 73, 'category_id': 91, 'bbox': [2, 154, 98, 2]}
# xmin, ymin, xmax, ymax : 10 134 134 6
# annotations:  {'image_id': 74, 'category_id': 91, 'bbox': [10, 134, 134, 6]}
# xmin, ymin, xmax, ymax : 38 122 94 12
# annotations:  {'image_id': 75, 'category_id': 91, 'bbox': [38, 94, 122, 12]}
# xmin, ymin, xmax, ymax : 11 97 155 11
# annotations:  {'image_id': 76, 'category_id': 91, 'bbox': [11, 155, 97, 11]}
# xmin, ymin, xmax, ymax : 1 105 142 1
# annotations:  {'image_id': 77, 'category_id': 91, 'bbox': [1, 142, 105, 1]}
# xmin, ymin, xmax, ymax : 98 33 14 132
# annotations:  {'image_id': 78, 'category_id': 91, 'bbox': [98, 14, 33, 132]}
# xmin, ymin, xmax, ymax : 26 43 51 93
# annotations:  {'image_id': 79, 'category_id': 91, 'bbox': [26, 51, 43, 93]}
# xmin, ymin, xmax, ymax : 45 11 69 70
# annotations:  {'image_id': 79, 'category_id': 91, 'bbox': [45, 69, 11, 70]}
# xmin, ymin, xmax, ymax : 72 14 97 85
# annotations:  {'image_id': 79, 'category_id': 91, 'bbox': [72, 97, 14, 85]}
# xmin, ymin, xmax, ymax : 71 106 122 84
# annotations:  {'image_id': 79, 'category_id': 91, 'bbox': [71, 122, 106, 84]}
# xmin, ymin, xmax, ymax : 100 83 119 8
# annotations:  {'image_id': 79, 'category_id': 91, 'bbox': [100, 119, 83, 8]}
# xmin, ymin, xmax, ymax : 120 0 138 32
# annotations:  {'image_id': 79, 'category_id': 91, 'bbox': [120, 138, 0, 32]}
# xmin, ymin, xmax, ymax : 7 5 44 118
# annotations:  {'image_id': 80, 'category_id': 91, 'bbox': [7, 44, 5, 118]}
# xmin, ymin, xmax, ymax : 11 129 129 9
# annotations:  {'image_id': 81, 'category_id': 91, 'bbox': [11, 129, 129, 9]}
# xmin, ymin, xmax, ymax : 0 139 107 0
# annotations:  {'image_id': 82, 'category_id': 91, 'bbox': [0, 107, 139, 0]}
# xmin, ymin, xmax, ymax : 9 130 119 27
# annotations:  {'image_id': 83, 'category_id': 91, 'bbox': [9, 119, 130, 27]}
# xmin, ymin, xmax, ymax : 20 131 152 87
# annotations:  {'image_id': 84, 'category_id': 91, 'bbox': [20, 152, 131, 87]}
# xmin, ymin, xmax, ymax : 65 100 2 4
# annotations:  {'image_id': 84, 'category_id': 91, 'bbox': [65, 2, 100, 4]}
# xmin, ymin, xmax, ymax : 53 1 102 102
# annotations:  {'image_id': 84, 'category_id': 91, 'bbox': [53, 102, 1, 102]}
# xmin, ymin, xmax, ymax : 92 102 159 0
# annotations:  {'image_id': 84, 'category_id': 91, 'bbox': [92, 159, 102, 0]}
# xmin, ymin, xmax, ymax : 25 69 66 136
# annotations:  {'image_id': 85, 'category_id': 91, 'bbox': [25, 66, 69, 136]}
# xmin, ymin, xmax, ymax : 11 45 137 134
# annotations:  {'image_id': 86, 'category_id': 91, 'bbox': [11, 137, 45, 134]}
# xmin, ymin, xmax, ymax : 4 72 157 7
# annotations:  {'image_id': 87, 'category_id': 91, 'bbox': [4, 157, 72, 7]}
# xmin, ymin, xmax, ymax : 14 3 122 130
# annotations:  {'image_id': 88, 'category_id': 91, 'bbox': [14, 122, 3, 130]}
# xmin, ymin, xmax, ymax : 125 123 60 31
# annotations:  {'image_id': 88, 'category_id': 91, 'bbox': [125, 60, 123, 31]}
# xmin, ymin, xmax, ymax : 3 107 160 10
# annotations:  {'image_id': 89, 'category_id': 91, 'bbox': [3, 160, 107, 10]}
# xmin, ymin, xmax, ymax : 5 8 26 68
# annotations:  {'image_id': 90, 'category_id': 91, 'bbox': [5, 26, 8, 68]}
# xmin, ymin, xmax, ymax : 31 6 53 67
# annotations:  {'image_id': 90, 'category_id': 91, 'bbox': [31, 53, 6, 67]}
# xmin, ymin, xmax, ymax : 53 7 76 68
# annotations:  {'image_id': 90, 'category_id': 91, 'bbox': [53, 76, 7, 68]}
# xmin, ymin, xmax, ymax : 78 8 102 67
# annotations:  {'image_id': 90, 'category_id': 91, 'bbox': [78, 102, 8, 67]}
# xmin, ymin, xmax, ymax : 103 5 129 70
# annotations:  {'image_id': 90, 'category_id': 91, 'bbox': [103, 129, 5, 70]}
# xmin, ymin, xmax, ymax : 130 4 154 67
# annotations:  {'image_id': 90, 'category_id': 91, 'bbox': [130, 154, 4, 67]}
# xmin, ymin, xmax, ymax : 2 2 162 92
# annotations:  {'image_id': 91, 'category_id': 91, 'bbox': [2, 162, 2, 92]}
# xmin, ymin, xmax, ymax : 6 10 135 99
# annotations:  {'image_id': 92, 'category_id': 91, 'bbox': [6, 135, 10, 99]}
# xmin, ymin, xmax, ymax : 35 18 108 64
# annotations:  {'image_id': 93, 'category_id': 91, 'bbox': [35, 108, 18, 64]}
# xmin, ymin, xmax, ymax : 55 93 155 57
# annotations:  {'image_id': 93, 'category_id': 91, 'bbox': [55, 155, 93, 57]}
# xmin, ymin, xmax, ymax : 6 42 94 77
# annotations:  {'image_id': 93, 'category_id': 91, 'bbox': [6, 94, 42, 77]}
# xmin, ymin, xmax, ymax : 36 22 69 79
# annotations:  {'image_id': 94, 'category_id': 91, 'bbox': [36, 69, 22, 79]}
# xmin, ymin, xmax, ymax : 68 16 93 90
# annotations:  {'image_id': 94, 'category_id': 91, 'bbox': [68, 93, 16, 90]}
# xmin, ymin, xmax, ymax : 95 15 122 85
# annotations:  {'image_id': 94, 'category_id': 91, 'bbox': [95, 122, 15, 85]}
# xmin, ymin, xmax, ymax : 10 10 148 99
# annotations:  {'image_id': 95, 'category_id': 91, 'bbox': [10, 148, 10, 99]}
# xmin, ymin, xmax, ymax : 10 56 83 17
# annotations:  {'image_id': 95, 'category_id': 91, 'bbox': [10, 83, 56, 17]}
# xmin, ymin, xmax, ymax : 6 8 158 105
# annotations:  {'image_id': 96, 'category_id': 91, 'bbox': [6, 158, 8, 105]}
# xmin, ymin, xmax, ymax : 5 139 137 -1
# annotations:  {'image_id': 97, 'category_id': 91, 'bbox': [5, 137, 139, -1]}
# xmin, ymin, xmax, ymax : 13 133 135 8
# annotations:  {'image_id': 98, 'category_id': 91, 'bbox': [13, 135, 133, 8]}
# xmin, ymin, xmax, ymax : 2 4 18 35
# annotations:  {'image_id': 99, 'category_id': 91, 'bbox': [2, 18, 4, 35]}
# xmin, ymin, xmax, ymax : 19 5 34 28
# annotations:  {'image_id': 99, 'category_id': 91, 'bbox': [19, 34, 5, 28]}
# xmin, ymin, xmax, ymax : 36 4 50 31
# annotations:  {'image_id': 99, 'category_id': 91, 'bbox': [36, 50, 4, 31]}
# xmin, ymin, xmax, ymax : 49 4 67 34
# annotations:  {'image_id': 99, 'category_id': 91, 'bbox': [49, 67, 4, 34]}
# xmin, ymin, xmax, ymax : 68 3 93 33
# annotations:  {'image_id': 99, 'category_id': 91, 'bbox': [68, 93, 3, 33]}
# xmin, ymin, xmax, ymax : 94 4 119 34
# annotations:  {'image_id': 99, 'category_id': 91, 'bbox': [94, 119, 4, 34]}
# xmin, ymin, xmax, ymax : 121 14 144 34
# annotations:  {'image_id': 99, 'category_id': 91, 'bbox': [121, 144, 14, 34]}
# xmin, ymin, xmax, ymax : 10 9 47 70
# annotations:  {'image_id': 100, 'category_id': 91, 'bbox': [10, 47, 9, 70]}
# xmin, ymin, xmax, ymax : 54 8 83 69
# annotations:  {'image_id': 100, 'category_id': 91, 'bbox': [54, 83, 8, 69]}
# xmin, ymin, xmax, ymax : 91 10 127 68
# annotations:  {'image_id': 100, 'category_id': 91, 'bbox': [91, 127, 10, 68]}
# xmin, ymin, xmax, ymax : 8 68 47 128
# annotations:  {'image_id': 100, 'category_id': 91, 'bbox': [8, 47, 68, 128]}
# xmin, ymin, xmax, ymax : 54 66 82 132
# annotations:  {'image_id': 100, 'category_id': 91, 'bbox': [54, 82, 66, 132]}
# xmin, ymin, xmax, ymax : 92 71 125 130
# annotations:  {'image_id': 100, 'category_id': 91, 'bbox': [92, 125, 71, 130]}
# xmin, ymin, xmax, ymax : 2 2 163 124
# annotations:  {'image_id': 101, 'category_id': 91, 'bbox': [2, 163, 2, 124]}
# xmin, ymin, xmax, ymax : 20 10 117 131
# annotations:  {'image_id': 102, 'category_id': 91, 'bbox': [20, 117, 10, 131]}
# xmin, ymin, xmax, ymax : 28 124 81 44
# annotations:  {'image_id': 102, 'category_id': 91, 'bbox': [28, 81, 124, 44]}
# xmin, ymin, xmax, ymax : 1 139 137 1
# annotations:  {'image_id': 103, 'category_id': 91, 'bbox': [1, 137, 139, 1]}
# xmin, ymin, xmax, ymax : 1 128 92 2
# annotations:  {'image_id': 104, 'category_id': 91, 'bbox': [1, 92, 128, 2]}
# Annotations saved to annotations_perso.json
